# %% [markdown]
# ## CSV Loas & Save

# %%
#
with open('./namsan.csv', encoding='EUC-KR') as f:
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,

# %%
#pandas 로 csv -> DataFrame 으로 불러오기
import pandas as pd
#encoding은 파일불러올때 매우 중요 
df = pd.read_csv('./namsan.csv', encoding='EUC-KR', low_memory=False)
df = pd.read_csv('./namsan.csv', encoding='EUC-KR', dtype={
    'ISBN': str, 
    '세트 ISBN':str, 
    '주제분류번호':str
})

# %%
#df.dtypes
df
# Out:
#             번호                                                도서명  \
# 0            1                                 감정을 이해하는 그림책 큐레이션
# 1            2                                  어른의 관계에는 마침표가 없다
# 2            3                               아무리 놀려도 괜찮은 책(독서치료용)
# 3            4                                나는 빛나는 3학년이야(독서치료용)
# 4            5  나는 왜 아무것도 하기 싫을까 :나도 모르게 방전된 몸과 마음을 회복하는 뇌과학 처방전
# ...        ...                                                ...
# 455551  455552                                          음악이 있는 풍경
# 455552  455553                                                큰오빠
# 455553  455554                                              뉴 웨이브
# 455554  455555                                       (최인훈 장편소설)화두
# 455555  455556                                       독일 문학과 세계 문학
#
#                                            저자     출판사  발행년도           ISBN  \
# 0       그림책심리성장연구소,강혜진,김애이,김은경,박소영,장미혜,차연주 지음      사우  2025  9791194126027
# ...

# %%
df.head(5)
# Out:
#    번호                                                도서명  \
# 0   1                                 감정을 이해하는 그림책 큐레이션
# 1   2                                  어른의 관계에는 마침표가 없다
# 2   3                               아무리 놀려도 괜찮은 책(독서치료용)
# 3   4                                나는 빛나는 3학년이야(독서치료용)
# 4   5  나는 왜 아무것도 하기 싫을까 :나도 모르게 방전된 몸과 마음을 회복하는 뇌과학 처방전
#
#                                       저자     출판사  발행년도           ISBN 세트 ISBN  \
# 0  그림책심리성장연구소,강혜진,김애이,김은경,박소영,장미혜,차연주 지음      사우  2025  9791194126027     NaN
# 1                                 김재식 지음  위즈덤하우스  2025  9791171714285     NaN
# 2                                    박티팔    곰세마리  2024  9791193366103     NaN
# 3                     곽유진, 최은옥, 김다노, 우미옥  위즈덤하우스  2025  9791192655956     NaN
# 4                                 배종빈 지음  포레스트북스  2025  9791194530374     NaN
#
#   부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0    0  NaN  181.7     1     0  2025-06-30          NaN
# ...

# %%
#저장도 가능 csv로 저장이 가능하다는 것은 
df.to_csv('./test.csv',encoding='utf -8', index=False)

# %% [markdown]
# ## Web API load

# %%
# Data Paesing (해석, 분석)
json_data = '{"a":1, "b": 2}' #json 은 무조건 ""로 지정해야함  딕셔너리로 변환하려면 반드시 파싱과정을 거쳐야함 
#json_data 는 아직 dict 로 해석이 되지 않았다. (아직 데이터가 파싱되지 않았다!)
#json_data['a'] #Error

import json 
dict_data = json.loads(json_data)
print()
# Out:
# {'a': 1, 'b': 2}

# %%
#Data Serializing (직렬화) [dict ->json]
dict_data = {'a':1, 'b': 2}

import json 
json_data =json.dumps(dict_data)

# %% [markdown]
# XML to json
# XML 은 HTML 의 상위버전이다.
# 이제는 josn 형태를 더 많이 쓰는 추세
# 왜냐면 데이터를 XML 이 두배로 쓰기 때문이다.
# XML은 dict 로 파싱할 수 있다.
# csv 나 api 로 안주면 아예 크롤링을 해서 데이터를 얻어야 한다.
